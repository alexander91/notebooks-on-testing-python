# %%
from pylab import *
plot([1,2,3])

# %%
# %matplotlib inline

from pylab import *
xs = range(-15, 15)
ys = [x*x for x in xs] 

plot(xs,ys)
grid()
xlabel('x')
ylabel('y')
title('myparabola')
show()

# %%
a = 5 + 1
print(a)
# Out:
# 6
